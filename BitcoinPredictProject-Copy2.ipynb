# %%
# =========================
# 1️⃣ 기본/유틸리티
# =========================
import os
import sys
import math
import time
import random
import datetime as dt
from pathlib import Path

import warnings
warnings.filterwarnings("ignore")

# =========================
# 2️⃣ 데이터 처리
# =========================
import numpy as np
import pandas as pd
from pandas.tseries.offsets import DateOffset
from sklearn.model_selection import train_test_split
# =========================
# 3️⃣ 시각화
# =========================
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# =========================
# 4️⃣ 데이터 전처리 / 스케일링
# =========================
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, KFold, TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# =========================
# 5️⃣ TensorFlow / Keras (LSTM, CNN-LSTM)
# =========================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input, Dense, LSTM, GRU, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.utils import plot_model

# =========================
# 6️⃣ PyTorch (옵션, CNN-LSTM 대안 또는 Transformer 시도)
# =========================
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# =========================
# 7️⃣ 앙상블 / 메타 모델
# =========================
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
import xgboost as xgb
import lightgbm as lgb

# =========================
# 8️⃣ 추가 유틸
# =========================
import joblib  # 모델 저장/불러오기
import json
import pickle
from tqdm import tqdm  # 진행률 표시

# =========================
# 9️⃣ 시계열 기술지표 (보조 feature)
# =========================
import ta  # RSI, MACD, BollingerBand 등


tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 50
#      45 from tensorflow.keras.utils import plot_model
#      47 # =========================
#      48 # 6️⃣ PyTorch (옵션, CNN-LSTM 대안 또는 Transformer 시도)
#      49 # =========================
# ---> 50 import torch
#      51 import torch.nn as nn
#      52 import torch.optim as optim
#
# File ~\anaconda3\envs\tf4\lib\site-packages\torch\__init__.py:278
#     274                     raise err
#     276         kernel32.SetErrorMode(prev_error_mode)
# --> 278     _load_dll_libraries()
#     279     del _load_dll_libraries
#     282 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     283     # Libraries can either be in path/nvidia/lib_folder/lib or path/lib_folder/lib
#
# File ~\anaconda3\envs\tf4\lib\site-packages\torch\__init__.py:261, in _load_dll_libraries()
#     257     err = ctypes.WinError(last_error)
#     258     err.strerror += (
#     259         f' Error loading "{dll}" or one of its dependencies.'
#     260     )
# --> 261     raise err
#     262 elif res is not None:
#     263     is_loaded = True
#
# OSError: [WinError 127] 지정된 프로시저를 찾을 수 없습니다. Error loading "C:\Users\cksgu\anaconda3\envs\tf4\lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.

# %%
df = pd.read_csv('btc_change_1.csv', index_col=0)

# %%
df.head()
# Out:
#                    Open time      Open      High       Low     Close  \
# 0  2018-01-01 00:00:00+00:00  13715.65  13818.55  12750.00  13380.00
# 1  2018-01-02 00:00:00+00:00  13382.16  15473.49  12890.02  14675.11
# 2  2018-01-03 00:00:00+00:00  14690.00  15307.56  14150.00  14919.51
# 3  2018-01-04 00:00:00+00:00  14919.51  15280.00  13918.04  15059.54
# 4  2018-01-05 00:00:00+00:00  15059.56  17176.24  14600.00  16960.39
#
#          Volume  Quote asset volume  Number of trades  \
# 0   8609.915844         114799747.4            105595
# 1  20078.092110         279717107.4            177728
# 2  15905.667640         236116868.3            162787
# 3  21329.649570         312781583.8            170310
# 4  23251.491130         369321956.5            192969
#
#    Taker buy base asset volume       SMA_14  ...  MACD  MACD_signal  \
# 0                  3961.938946  14791.98429  ...   0.0          0.0
# 1                 11346.326740  14791.98429  ...   0.0          0.0
# 2                  8994.953566  14791.98429  ...   0.0          0.0
# 3                 12680.812950  14791.98429  ...   0.0          0.0
# 4                 13346.622290  14791.98429  ...   0.0          0.0
#
#    MACD_hist      STO_K      STO_D  STO_RSI_K  STO_RSI_D           OBV  \
# 0        0.0  35.922849  31.959339   0.813677   0.650675   8609.915844
# 1        0.0  35.922849  31.959339   0.813677   0.650675  28688.007960
# 2        0.0  35.922849  31.959339   0.813677   0.650675  44593.675590
# 3        0.0  35.922849  31.959339   0.813677   0.650675  65923.325170
# 4        0.0  35.922849  31.959339   0.813677   0.650675  89174.816290
#
#     change  change_rate
# 0     0.00     0.000000
# 1 -1295.11    -0.096794
# 2  -244.40    -0.016654
# 3  -140.03    -0.009386
# 4 -1900.85    -0.126222
#
# [5 rows x 22 columns]

# %%
# df = df.drop(columns=['Ignore'])
# ==========================
# 2️⃣ 시간 컬럼 처리 (인덱스로 설정)
# ==========================
df['Open time'] = pd.to_datetime(df['Open time'])
df = df.set_index('Open time')

# ==========================
# 3️⃣ 숫자형 컬럼만 선택
# ==========================
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
df_numeric = df[numeric_cols]

# ==========================
# 4️⃣ MinMaxScaler 적용
# ==========================
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_numeric),
                         columns=numeric_cols,
                         index=df.index)

# ==========================
# 5️⃣ 결과 확인
# ==========================
df_scaled.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Open time
# 2018-01-01 00:00:00+00:00  0.087464  0.086982  0.079884  0.084484  0.010856
# 2018-01-02 00:00:00+00:00  0.084687  0.100637  0.081050  0.095245  0.025939
# 2018-01-03 00:00:00+00:00  0.095577  0.099268  0.091542  0.097276  0.020452
# 2018-01-04 00:00:00+00:00  0.097488  0.099041  0.089610  0.098439  0.027585
# 2018-01-05 00:00:00+00:00  0.098654  0.114687  0.095289  0.114232  0.030113
#
#                            Quote asset volume  Number of trades  \
# Open time
# 2018-01-01 00:00:00+00:00            0.005903          0.006126
# 2018-01-02 00:00:00+00:00            0.015352          0.010868
# 2018-01-03 00:00:00+00:00            0.012854          0.009885
# 2018-01-04 00:00:00+00:00            0.017246          0.010380
# 2018-01-05 00:00:00+00:00            0.020486          0.011870
#
#                            Taker buy base asset volume    SMA_14    EMA_14  \
# Open time
# 2018-01-01 00:00:00+00:00                     0.010144  0.098989  0.094623
# 2018-01-02 00:00:00+00:00                     0.029856  0.098989  0.094623
# 2018-01-03 00:00:00+00:00                     0.023579  0.098989  0.094623
# 2018-01-04 00:00:00+00:00                     0.033418  0.098989  0.094623
# 2018-01-05 00:00:00+00:00                     0.035196  0.098989  0.094623
#
#                            ...      MACD  MACD_signal  MACD_hist     STO_K  \
# Open time                  ...
# 2018-01-01 00:00:00+00:00  ...  0.419545     0.409292    0.48067  0.357947
# 2018-01-02 00:00:00+00:00  ...  0.419545     0.409292    0.48067  0.357947
# 2018-01-03 00:00:00+00:00  ...  0.419545     0.409292    0.48067  0.357947
# 2018-01-04 00:00:00+00:00  ...  0.419545     0.409292    0.48067  0.357947
# 2018-01-05 00:00:00+00:00  ...  0.419545     0.409292    0.48067  0.357947
#
#                               STO_D  STO_RSI_K  STO_RSI_D       OBV    change  \
# Open time
# 2018-01-01 00:00:00+00:00  0.306889   0.813677   0.650675  0.468852  0.507000
# 2018-01-02 00:00:00+00:00  0.306889   0.813677   0.650675  0.471082  0.427679
# 2018-01-03 00:00:00+00:00  0.306889   0.813677   0.650675  0.472849  0.492031
# 2018-01-04 00:00:00+00:00  0.306889   0.813677   0.650675  0.475218  0.498424
# 2018-01-05 00:00:00+00:00  0.306889   0.813677   0.650675  0.477800  0.390579
#
#                            change_rate
# Open time
# 2018-01-01 00:00:00+00:00     0.330891
# 2018-01-02 00:00:00+00:00     0.166947
# 2018-01-03 00:00:00+00:00     0.302684
# 2018-01-04 00:00:00+00:00     0.314994
# 2018-01-05 00:00:00+00:00     0.117104
#
# [5 rows x 21 columns]

# %%
# ==========================
# 결측치 확인
# ==========================
# 각 컬럼별 결측치 개수
print("컬럼별 결측치 개수:")
print(df.isna().sum())

# 각 컬럼별 결측치 비율 (%)
print("\n컬럼별 결측치 비율 (%):")
print(df.isna().mean() * 100)

# 전체 데이터셋 결측치 총합
print(f"\n전체 결측치 총합: {df.isna().sum().sum()}")
# Out:
# 컬럼별 결측치 개수:
# Open                           0
# High                           0
# Low                            0
# Close                          0
# Volume                         0
# Quote asset volume             0
# Number of trades               0
# Taker buy base asset volume    0
# SMA_14                         0
# EMA_14                         0
# RSI_14                         0
# MACD                           0
# MACD_signal                    0
# MACD_hist                      0
# STO_K                          0
# STO_D                          0
# STO_RSI_K                      0
# STO_RSI_D                      0
# OBV                            0
# change                         0
# change_rate                    0
# dtype: int64
#
# 컬럼별 결측치 비율 (%):
# Open                           0.0
# High                           0.0
# Low                            0.0
# Close                          0.0
# Volume                         0.0
# Quote asset volume             0.0
# Number of trades               0.0
# Taker buy base asset volume    0.0
# SMA_14                         0.0
# EMA_14                         0.0
# RSI_14                         0.0
# MACD                           0.0
# MACD_signal                    0.0
# MACD_hist                      0.0
# STO_K                          0.0
# STO_D                          0.0
# STO_RSI_K                      0.0
# STO_RSI_D                      0.0
# OBV                            0.0
# change                         0.0
# change_rate                    0.0
# dtype: float64
#
# 전체 결측치 총합: 0

# %%
# 전체 데이터를 먼저 85% / 15%로 나눠서 Test 확보
train_val_df, test_df = train_test_split(df_scaled, test_size=0.15, shuffle=False)

# train_val을 82.35% / 17.65%로 나눠서 Train/Validation 비율 맞춤
# 계산: 0.15 / 0.85 ≈ 0.1765
train_df, val_df = train_test_split(train_val_df, test_size=0.1765, shuffle=False)

print(f"Train shape: {train_df.shape}, Val shape: {val_df.shape}, Test shape: {test_df.shape}")
# Out:
# Train shape: (1957, 21), Val shape: (420, 21), Test shape: (420, 21)

# %%
seq_len = 6

def create_window_sequences(df, seq_len, predict_col='change_rate'):
    values = df.values
    X, y = [], []
    predict_idx = df.columns.get_loc(predict_col)

    for i in range(seq_len, len(values)):
        X.append(values[i-seq_len:i])
        y.append(values[i, predict_idx])

    return np.array(X), np.array(y)

# %%
X_train, y_train = create_window_sequences(train_df, seq_len)
X_val, y_val = create_window_sequences(val_df, seq_len)
X_test, y_test = create_window_sequences(test_df, seq_len)

print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")
print(f"X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# X_train: (1951, 6, 21), y_train: (1951,)
# X_val: (414, 6, 21), y_val: (414,)
# X_test: (414, 6, 21), y_test: (414,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(96, input_shape=input_shape, return_sequences=False))
    model.add(Dropout(0.16103971350555243))
    model.add(Dense(1, activation='linear'))  # 다음 날 Close 예측
    model.compile(optimizer=Adam(learning_rate=0.005889363347033941), loss='mse', metrics=['mae'])
    return model

lstm_model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 96)                  │          45,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 96)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              97 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 45,409 (177.38 KB)
#  Trainable params: 45,409 (177.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, TimeDistributed, Reshape

def build_cnn_lstm_model(input_shape):
    model = Sequential()
    # CNN 레이어
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2))
    # LSTM 레이어
    model.add(LSTM(64, return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
    return model

cnn_lstm_model = build_cnn_lstm_model((X_train.shape[1], X_train.shape[2]))
cnn_lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 4, 32)               │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 2, 32)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,945 (105.25 KB)
#  Trainable params: 26,945 (105.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# LSTM 학습
lstm_history = lstm_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0150 - mae: 0.0825 - val_loss: 0.0019 - val_mae: 0.0306
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0503 - val_loss: 0.0018 - val_mae: 0.0309
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0518 - val_loss: 0.0018 - val_mae: 0.0290
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0499 - val_loss: 0.0018 - val_mae: 0.0299
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0495 - val_loss: 0.0020 - val_mae: 0.0327
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0486 - val_loss: 0.0019 - val_mae: 0.0313
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0481 - val_loss: 0.0019 - val_mae: 0.0313
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0476 - val_loss: 0.0019 - val_mae: 0.0313
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0475 - val_loss: 0.0018 - val_mae: 0.0303
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0472 - val_loss: 0.0022 - val_mae: 0.0346
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0473 - val_loss: 0.0019 - val_mae: 0.0317
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0464 - val_loss: 0.0022 - val_mae: 0.0344
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0465 - val_loss: 0.0020 - val_mae: 0.0328
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mae: 0.0468 - val_loss: 0.0022 - val_mae: 0.0354
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0463 - val_loss: 0.0022 - val_mae: 0.0352
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0460 - val_loss: 0.0023 - val_mae: 0.0357
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0457 - val_loss: 0.0022 - val_mae: 0.0344
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0453 - val_loss: 0.0022 - val_mae: 0.0347
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0451 - val_loss: 0.0023 - val_mae: 0.0356
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0459 - val_loss: 0.0023 - val_mae: 0.0365
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0456 - val_loss: 0.0023 - val_mae: 0.0362
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0453 - val_loss: 0.0023 - val_mae: 0.0363
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0452 - val_loss: 0.0024 - val_mae: 0.0375

# %%
# CNN-LSTM 학습
cnn_lstm_history = cnn_lstm_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048 - mae: 0.0401 - val_loss: 4.1414e-04 - val_mae: 0.0141
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1274e-04 - mae: 0.0177 - val_loss: 5.7898e-04 - val_mae: 0.0172
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0711e-04 - mae: 0.0167 - val_loss: 5.2799e-04 - val_mae: 0.0161
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2516e-04 - mae: 0.0155 - val_loss: 4.2731e-04 - val_mae: 0.0149
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6779e-04 - mae: 0.0151 - val_loss: 4.7058e-04 - val_mae: 0.0151
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8973e-04 - mae: 0.0141 - val_loss: 6.3944e-04 - val_mae: 0.0176
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9900e-04 - mae: 0.0139 - val_loss: 5.4829e-04 - val_mae: 0.0161
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6785e-04 - mae: 0.0138 - val_loss: 9.3330e-04 - val_mae: 0.0223
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3971e-04 - mae: 0.0131 - val_loss: 5.6985e-04 - val_mae: 0.0165
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0172e-04 - mae: 0.0127 - val_loss: 6.1173e-04 - val_mae: 0.0175
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7922e-04 - mae: 0.0121 - val_loss: 6.2951e-04 - val_mae: 0.0179
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9268e-04 - mae: 0.0125 - val_loss: 0.0019 - val_mae: 0.0356
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6510e-04 - mae: 0.0121 - val_loss: 6.9567e-04 - val_mae: 0.0190
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8673e-04 - mae: 0.0122 - val_loss: 7.7127e-04 - val_mae: 0.0202
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3880e-04 - mae: 0.0116 - val_loss: 0.0011 - val_mae: 0.0266
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4200e-04 - mae: 0.0113 - val_loss: 3.2520e-04 - val_mae: 0.0119
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0395e-04 - mae: 0.0110 - val_loss: 9.2458e-04 - val_mae: 0.0236
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3727e-04 - mae: 0.0115 - val_loss: 8.9701e-04 - val_mae: 0.0227
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1602e-04 - mae: 0.0111 - val_loss: 0.0011 - val_mae: 0.0253
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9260e-04 - mae: 0.0109 - val_loss: 4.7074e-04 - val_mae: 0.0147

# %%
# ==========================
# LSTM 모델 성능 평가
# ==========================
val_loss_lstm, val_mae_lstm = lstm_model.evaluate(X_val, y_val, verbose=0)
test_loss_lstm, test_mae_lstm = lstm_model.evaluate(X_test, y_test, verbose=0)

print(f"LSTM 검증 손실(MSE): {val_loss_lstm:.6f}, MAE: {val_mae_lstm:.6f}")
print(f"LSTM 테스트 손실(MSE): {test_loss_lstm:.6f}, MAE: {test_mae_lstm:.6f}")
# Out:
# LSTM 검증 손실(MSE): 0.001761, MAE: 0.029037
# LSTM 테스트 손실(MSE): 0.001766, MAE: 0.030006

# %%
# ==========================
# CNN-LSTM 모델 성능 평가
# ==========================
val_loss_cnn_lstm, val_mae_cnn_lstm = cnn_lstm_model.evaluate(X_val, y_val, verbose=0)
test_loss_cnn_lstm, test_mae_cnn_lstm = cnn_lstm_model.evaluate(X_test, y_test, verbose=0)

print(f"CNN-LSTM 검증 손실(MSE): {val_loss_cnn_lstm:.6f}, MAE: {val_mae_cnn_lstm:.6f}")
print(f"CNN-LSTM 테스트 손실(MSE): {test_loss_cnn_lstm:.6f}, MAE: {test_mae_cnn_lstm:.6f}")
# Out:
# CNN-LSTM 검증 손실(MSE): 0.066343, MAE: 0.253338
# CNN-LSTM 테스트 손실(MSE): 0.071690, MAE: 0.263383

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==========================
# y_true, y_pred 복원
# ==========================
close_idx = df_scaled.columns.get_loc("Close")

# 실제 값 복원
y_true_real = scaler.inverse_transform(
    np.concatenate([
        np.zeros((len(y_test), close_idx)),
        y_test.reshape(-1,1),
        np.zeros((len(y_test), df_scaled.shape[1]-close_idx-1))
    ], axis=1)
)[:, close_idx]

# LSTM 예측 복원
y_pred_lstm = lstm_model.predict(X_test)
y_pred_lstm_real = scaler.inverse_transform(
    np.concatenate([
        np.zeros((len(y_pred_lstm), close_idx)),
        y_pred_lstm,
        np.zeros((len(y_pred_lstm), df_scaled.shape[1]-close_idx-1))
    ], axis=1)
)[:, close_idx]

# CNN-LSTM 예측 복원
# y_pred_cnn_lstm = cnn_lstm_model.predict(X_test)
# y_pred_cnn_lstm_real = scaler.inverse_transform(
#     np.concatenate([
#         np.zeros((len(y_pred_cnn_lstm), close_idx)),
#         y_pred_cnn_lstm,
#         np.zeros((len(y_pred_cnn_lstm), df_scaled.shape[1]-close_idx-1))
#     ], axis=1)
# )[:, close_idx]


# ==========================
# 테스트셋 인덱스 복원 (윈도우 마지막 날짜들)
# ==========================
test_dates = df.index[-len(y_test):]  # X_test에 대응하는 날짜 추출

# ==========================
# 시각화
# ==========================
plt.figure(figsize=(15,6))
plt.plot(test_dates, y_true_real, label='Actual Close', color='black')
plt.plot(test_dates, y_pred_lstm_real, label='LSTM Predicted', color='blue')
# plt.plot(test_dates, y_pred_cnn_lstm_real, label='CNN-LSTM Predicted', color='red', alpha=0.7)
plt.title('Bitcoin Close Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
plt.figure(figsize=(15,6))
plt.plot(test_dates[-30:], y_test[-30:], label='Actual Close', color='black')
plt.plot(test_dates[-30:],y_pred_lstm[-30:])

# %%
plt.figure(figsize=(15,6))
plt.plot(test_dates[-30:], y_true_real[-30:], label='Actual Close', color='black')
plt.plot(test_dates[-30:],y_pred_lstm_real[-30:])

# %%
train_idx = df_scaled.index[:len(y_train)]
val_idx   = df_scaled.index[len(y_train): len(y_train)+len(y_val)]

# %%
import matplotlib.pyplot as plt

# ==========================
# 1️⃣ Train 예측
# ==========================
y_pred_train = lstm_model.predict(X_train)
y_pred_train_real = scaler.inverse_transform(
    np.concatenate([np.zeros((len(y_pred_train), close_idx)),
                    y_pred_train,
                    np.zeros((len(y_pred_train), df_scaled.shape[1]-close_idx-1))], axis=1)
)[:, close_idx]

y_true_train_real = scaler.inverse_transform(
    np.concatenate([np.zeros((len(y_train), close_idx)),
                    y_train.reshape(-1,1),
                    np.zeros((len(y_train), df_scaled.shape[1]-close_idx-1))], axis=1)
)[:, close_idx]

plt.figure(figsize=(15,6))
plt.plot(train_idx, y_true_train_real, label='Actual Train', color='black')
plt.plot(train_idx, y_pred_train_real, label='LSTM Predicted Train', color='blue')
plt.title('Train Set Prediction')
plt.xlabel('Date')
plt.ylabel('BTC Close Price (USD)')
plt.legend()
plt.show()

# ==========================
# 2️⃣ Validation 예측
# ==========================
y_pred_val = lstm_model.predict(X_val)
y_pred_val_real = scaler.inverse_transform(
    np.concatenate([np.zeros((len(y_pred_val), close_idx)),
                    y_pred_val,
                    np.zeros((len(y_pred_val), df_scaled.shape[1]-close_idx-1))], axis=1)
)[:, close_idx]

y_true_val_real = scaler.inverse_transform(
    np.concatenate([np.zeros((len(y_val), close_idx)),
                    y_val.reshape(-1,1),
                    np.zeros((len(y_val), df_scaled.shape[1]-close_idx-1))], axis=1)
)[:, close_idx]

plt.figure(figsize=(15,6))
plt.plot(val_idx, y_true_val_real, label='Actual Validation', color='black')
plt.plot(val_idx, y_pred_val_real, label='LSTM Predicted Validation', color='blue')
plt.title('Validation Set Prediction')
plt.xlabel('Date')
plt.ylabel('BTC Close Price (USD)')
plt.legend()
plt.show()
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# !pip install --upgrade xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.0.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.1)

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import numpy as np

# ==========================
# 1. Base 모델 예측값 생성
# ==========================
y_train_pred_lstm = lstm_model.predict(X_train)
y_val_pred_lstm   = lstm_model.predict(X_val)
y_test_pred_lstm  = lstm_model.predict(X_test)

y_train_pred_cnn  = cnn_lstm_model.predict(X_train)
y_val_pred_cnn    = cnn_lstm_model.predict(X_val)
y_test_pred_cnn   = cnn_lstm_model.predict(X_test)

# ==========================
# 2. 스태킹 데이터셋 만들기
# ==========================
stacked_X_train = np.hstack([y_train_pred_lstm, y_train_pred_cnn])
stacked_X_val   = np.hstack([y_val_pred_lstm, y_val_pred_cnn])
stacked_X_test  = np.hstack([y_test_pred_lstm, y_test_pred_cnn])

stacked_y_train = y_train
stacked_y_val   = y_val
stacked_y_test  = y_test

# ==========================
# 3. 메타모델 (XGBoost)
# ==========================
meta_model = XGBRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=3,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

meta_model.fit(stacked_X_train, stacked_y_train)

# ==========================
# 4. 최종 예측
# ==========================
y_val_pred_stack  = meta_model.predict(stacked_X_val)
y_test_pred_stack = meta_model.predict(stacked_X_test)

# ==========================
# 5. 성능 평가
# ==========================
val_mse = mean_squared_error(stacked_y_val, y_val_pred_stack)
val_mae = mean_absolute_error(stacked_y_val, y_val_pred_stack)

test_mse = mean_squared_error(stacked_y_test, y_test_pred_stack)
test_mae = mean_absolute_error(stacked_y_test, y_test_pred_stack)

print(f"스태킹(XGBoost) 검증 MSE: {val_mse:.4f}, MAE: {val_mae:.4f}")
print(f"스태킹(XGBoost) 테스트 MSE: {test_mse:.4f}, MAE: {test_mae:.4f}")
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 스태킹(XGBoost) 검증 MSE: 0.0004, MAE: 0.0136
# 스태킹(XGBoost) 테스트 MSE: 0.0735, MAE: 0.2304

# %%
import optuna

# %%
def objective(trial):
    """Optuna가 최적의 하이퍼파라미터를 찾기 위해 실행하는 함수"""
    
    # ==========================
    # 1. 튜닝할 하이퍼파라미터 정의
    # ==========================
    seq_len = trial.suggest_int('seq_len', 5, 30)
    # LSTM 레이어 수
    n_layers = trial.suggest_int('n_layers', 1, 3)
    # 각 LSTM 레이어의 유닛 수
    lstm_units = trial.suggest_int('lstm_units', 32, 256, step=32)
    # Dropout 비율
    dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
    # 학습률 (Learning Rate)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    # 배치 사이즈
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])


    X_train, y_train = create_window_sequences(train_df, seq_len)
    X_val, y_val = create_window_sequences(val_df, seq_len)

    # 만약 제안된 seq_len이 너무 길어서 validation set을 만들 수 없는 경우,
    # 해당 trial을 중단하고 다음 trial로 넘어갑니다 (Pruning).
    if len(X_val) == 0:
        raise optuna.exceptions.TrialPruned()
    
    # ==========================
    # 2. 모델 구성
    # ==========================
    model = Sequential()
    
    # 동적으로 LSTM 레이어 추가
    for i in range(n_layers):
        # 마지막 레이어가 아니면 return_sequences=True
        return_sequences = (i < n_layers - 1)
        if i == 0: # 첫 번째 레이어는 input_shape 지정
            model.add(LSTM(units=lstm_units, return_sequences=return_sequences, 
                           input_shape=(X_train.shape[1], X_train.shape[2])))
        else:
            model.add(LSTM(units=lstm_units, return_sequences=return_sequences))
        model.add(Dropout(dropout_rate))
            
    model.add(Dense(1, activation='linear'))

    # ==========================
    # 3. 모델 컴파일
    # ==========================
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
    
    # ==========================
    # 4. 모델 학습
    # ==========================
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=0  # 학습 과정 출력 생략
    )
    
    # ==========================
    # 5. 검증 데이터로 성능 평가 후 결과 반환
    # ==========================
    val_loss, _ = model.evaluate(X_val, y_val, verbose=0)
    
    return val_loss # 최소화할 목표인 검증 손실(MSE)을 반환

# %%
# ==============================================================================
# Optuna Study 생성 및 최적화 실행
# ==============================================================================

# Study 객체 생성. 'minimize'는 objective 함수가 반환하는 값을 최소화하는 것을 목표로 함
study = optuna.create_study(direction='minimize')

# n_trials 만큼 최적화 시도
# 시간을 절약하기 위해 50회로 설정했지만, 더 나은 결과를 위해 100회 이상 시도하는 것을 권장합니다.
study.optimize(objective, n_trials=100) # 600초(10분) 제한 추가 가능
# Out:
# [I 2025-09-10 11:25:18,648] A new study created in memory with name: no-name-452dacf3-42bd-42fb-89d2-8cba8b9afc0f
# [I 2025-09-10 11:25:59,966] Trial 0 finished with value: 0.00023292854893952608 and parameters: {'seq_len': 27, 'n_layers': 2, 'lstm_units': 224, 'dropout_rate': 0.14478877514636035, 'learning_rate': 0.005780387573741923, 'batch_size': 32}. Best is trial 0 with value: 0.00023292854893952608.
# [I 2025-09-10 11:26:24,582] Trial 1 finished with value: 0.00014812768495175987 and parameters: {'seq_len': 21, 'n_layers': 1, 'lstm_units': 160, 'dropout_rate': 0.3324204224623587, 'learning_rate': 0.0006272402320939649, 'batch_size': 32}. Best is trial 1 with value: 0.00014812768495175987.
# [I 2025-09-10 11:27:25,678] Trial 2 finished with value: 0.00019052429706789553 and parameters: {'seq_len': 19, 'n_layers': 2, 'lstm_units': 256, 'dropout_rate': 0.3538808114526065, 'learning_rate': 0.000500304526889798, 'batch_size': 64}. Best is trial 1 with value: 0.00014812768495175987.
# [I 2025-09-10 11:28:22,959] Trial 3 finished with value: 0.000172866799402982 and parameters: {'seq_len': 22, 'n_layers': 3, 'lstm_units': 96, 'dropout_rate': 0.49794265731253584, 'learning_rate': 0.004256101022064213, 'batch_size': 16}. Best is trial 1 with value: 0.00014812768495175987.
# [I 2025-09-10 11:28:50,799] Trial 4 finished with value: 0.00020693676196970046 and parameters: {'seq_len': 21, 'n_layers': 1, 'lstm_units': 256, 'dropout_rate': 0.40861989704915125, 'learning_rate': 0.000264908633186341, 'batch_size': 32}. Best is trial 1 with value: 0.00014812768495175987.
# [I 2025-09-10 11:29:33,027] Trial 5 finished with value: 0.00013647241576109082 and parameters: {'seq_len': 27, 'n_layers': 1, 'lstm_units': 192, 'dropout_rate': 0.41754911490098656, 'learning_rate': 0.0008830060498138314, 'batch_size': 16}. Best is trial 5 with value: 0.00013647241576109082.
# [I 2025-09-10 11:30:25,170] Trial 6 finished with value: 0.00017000779916998 and parameters: {'seq_len': 28, 'n_layers': 2, 'lstm_units': 160, 'dropout_rate': 0.36358692268197423, 'learning_rate': 0.0008046276946034802, 'batch_size': 16}. Best is trial 5 with value: 0.00013647241576109082.
# [I 2025-09-10 11:31:51,198] Trial 7 finished with value: 0.0003206620167475194 and parameters: {'seq_len': 27, 'n_layers': 3, 'lstm_units': 256, 'dropout_rate': 0.3714283135694493, 'learning_rate': 0.002384891673257448, 'batch_size': 16}. Best is trial 5 with value: 0.00013647241576109082.
# [I 2025-09-10 11:31:56,947] Trial 8 finished with value: 0.00038228544872254133 and parameters: {'seq_len': 12, 'n_layers': 2, 'lstm_units': 96, 'dropout_rate': 0.34246631061672894, 'learning_rate': 0.0013144034916750325, 'batch_size': 64}. Best is trial 5 with value: 0.00013647241576109082.
# [I 2025-09-10 11:33:52,890] Trial 9 finished with value: 0.0001910348073579371 and parameters: {'seq_len': 18, 'n_layers': 3, 'lstm_units': 192, 'dropout_rate': 0.30505502672493756, 'learning_rate': 0.00024041521182644498, 'batch_size': 32}. Best is trial 5 with value: 0.00013647241576109082.
# [I 2025-09-10 11:34:07,512] Trial 10 finished with value: 0.00016962918743956834 and parameters: {'seq_len': 5, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.1882895162781591, 'learning_rate': 0.00012506266782078568, 'batch_size': 16}. Best is trial 5 with value: 0.00013647241576109082.
# [I 2025-09-10 11:34:26,135] Trial 11 finished with value: 0.00013346929335966706 and parameters: {'seq_len': 23, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.23189324283695795, 'learning_rate': 0.0013646891569271378, 'batch_size': 32}. Best is trial 11 with value: 0.00013346929335966706.
# [I 2025-09-10 11:34:46,276] Trial 12 finished with value: 0.00012158358003944159 and parameters: {'seq_len': 25, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.22566553923786692, 'learning_rate': 0.001803662085606109, 'batch_size': 32}. Best is trial 12 with value: 0.00012158358003944159.
# [I 2025-09-10 11:35:09,200] Trial 13 finished with value: 0.00011027562140952796 and parameters: {'seq_len': 14, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.2250148844084959, 'learning_rate': 0.0025740468972361348, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:35:23,334] Trial 14 finished with value: 0.00011410976730985567 and parameters: {'seq_len': 14, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.23569768897100155, 'learning_rate': 0.009720409353575902, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:35:39,452] Trial 15 finished with value: 0.00012259650975465775 and parameters: {'seq_len': 13, 'n_layers': 2, 'lstm_units': 64, 'dropout_rate': 0.10271751637099116, 'learning_rate': 0.009771396435118445, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:35:51,144] Trial 16 finished with value: 0.00011640535376500338 and parameters: {'seq_len': 13, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.25501073725313095, 'learning_rate': 0.0033767875468298167, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:35:58,814] Trial 17 finished with value: 0.0001317454152740538 and parameters: {'seq_len': 10, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.2617969276967942, 'learning_rate': 0.008570390913512258, 'batch_size': 64}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:36:09,739] Trial 18 finished with value: 0.0001114724000217393 and parameters: {'seq_len': 16, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.15926098376183734, 'learning_rate': 0.005705983397204319, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:36:41,464] Trial 19 finished with value: 0.00011706871737260371 and parameters: {'seq_len': 16, 'n_layers': 2, 'lstm_units': 96, 'dropout_rate': 0.1706065693051745, 'learning_rate': 0.0028374954902038126, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:36:47,375] Trial 20 finished with value: 0.0002967281616292894 and parameters: {'seq_len': 9, 'n_layers': 2, 'lstm_units': 128, 'dropout_rate': 0.11713941809326656, 'learning_rate': 0.00530199505612509, 'batch_size': 64}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:37:01,206] Trial 21 finished with value: 0.00011357274343026802 and parameters: {'seq_len': 16, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.20464005379063438, 'learning_rate': 0.005274991512541133, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:37:10,715] Trial 22 finished with value: 0.00012411973148118705 and parameters: {'seq_len': 16, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.1937091741378381, 'learning_rate': 0.006155939573823722, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:37:29,561] Trial 23 finished with value: 0.0001104670373024419 and parameters: {'seq_len': 16, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.14995478565646245, 'learning_rate': 0.0022728863154524077, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:37:35,195] Trial 24 finished with value: 0.00015964686463121325 and parameters: {'seq_len': 9, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.15123534513194264, 'learning_rate': 0.002018236522510881, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:37:46,356] Trial 25 finished with value: 0.00012502535537350923 and parameters: {'seq_len': 19, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.1494687919060992, 'learning_rate': 0.0034456704988118664, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:37:56,950] Trial 26 finished with value: 0.0001360858150292188 and parameters: {'seq_len': 11, 'n_layers': 1, 'lstm_units': 96, 'dropout_rate': 0.2833922326062603, 'learning_rate': 0.0014049178312911942, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:38:15,413] Trial 27 finished with value: 0.00011057082156185061 and parameters: {'seq_len': 7, 'n_layers': 2, 'lstm_units': 32, 'dropout_rate': 0.12224488484217101, 'learning_rate': 0.0024908752070340666, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:38:26,152] Trial 28 finished with value: 0.00013518233026843518 and parameters: {'seq_len': 5, 'n_layers': 2, 'lstm_units': 64, 'dropout_rate': 0.1345631994790715, 'learning_rate': 0.002160013021634475, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:39:01,443] Trial 29 finished with value: 0.0001267147163162008 and parameters: {'seq_len': 8, 'n_layers': 3, 'lstm_units': 128, 'dropout_rate': 0.123914738910396, 'learning_rate': 0.0011708144553835296, 'batch_size': 64}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:39:22,289] Trial 30 finished with value: 0.00011979307600995526 and parameters: {'seq_len': 7, 'n_layers': 2, 'lstm_units': 32, 'dropout_rate': 0.1794861390738836, 'learning_rate': 0.002967434235383784, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:39:28,179] Trial 31 finished with value: 0.00018243768136017025 and parameters: {'seq_len': 15, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.15841321451483906, 'learning_rate': 0.006861528985327734, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:39:44,425] Trial 32 finished with value: 0.00011355907918186858 and parameters: {'seq_len': 18, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.2098808665606005, 'learning_rate': 0.0042241127797443215, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:39:59,864] Trial 33 finished with value: 0.00014628628559876233 and parameters: {'seq_len': 20, 'n_layers': 2, 'lstm_units': 32, 'dropout_rate': 0.10626124715005927, 'learning_rate': 0.004383186000862469, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:40:37,856] Trial 34 finished with value: 0.00011398209608159959 and parameters: {'seq_len': 14, 'n_layers': 2, 'lstm_units': 64, 'dropout_rate': 0.13182149819521052, 'learning_rate': 0.0016593657312008645, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:41:07,208] Trial 35 finished with value: 0.00011820526560768485 and parameters: {'seq_len': 17, 'n_layers': 1, 'lstm_units': 96, 'dropout_rate': 0.17013320274335839, 'learning_rate': 0.0006019793558542071, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:41:31,591] Trial 36 finished with value: 0.00014700283645652235 and parameters: {'seq_len': 11, 'n_layers': 3, 'lstm_units': 32, 'dropout_rate': 0.14354115810035345, 'learning_rate': 0.0024277834713904395, 'batch_size': 32}. Best is trial 13 with value: 0.00011027562140952796.
# [I 2025-09-10 11:41:44,466] Trial 37 finished with value: 0.00011003133840858936 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.21369056625942195, 'learning_rate': 0.0038725677297528206, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:42:04,614] Trial 38 finished with value: 0.00011099359107902274 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.3093660966008972, 'learning_rate': 0.0039192042637204196, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:42:26,587] Trial 39 finished with value: 0.00014750284026376903 and parameters: {'seq_len': 6, 'n_layers': 2, 'lstm_units': 64, 'dropout_rate': 0.2673511310264859, 'learning_rate': 0.0009382119220125781, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:42:56,302] Trial 40 finished with value: 0.00020584726007655263 and parameters: {'seq_len': 10, 'n_layers': 3, 'lstm_units': 96, 'dropout_rate': 0.21551403195803934, 'learning_rate': 0.002681158211775399, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:43:23,622] Trial 41 finished with value: 0.00011105036537628621 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.39268039217171813, 'learning_rate': 0.0035394970777140587, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:43:52,284] Trial 42 finished with value: 0.0001327132631558925 and parameters: {'seq_len': 30, 'n_layers': 1, 'lstm_units': 160, 'dropout_rate': 0.29293103072161714, 'learning_rate': 0.00426002576217796, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:44:14,906] Trial 43 finished with value: 0.00011517492384882644 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.3193104414567015, 'learning_rate': 0.007085540964483507, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:44:20,700] Trial 44 finished with value: 0.00017086915613617748 and parameters: {'seq_len': 5, 'n_layers': 1, 'lstm_units': 192, 'dropout_rate': 0.3469158297470599, 'learning_rate': 0.0016712027877507731, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:44:32,916] Trial 45 finished with value: 0.00017489914898760617 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 256, 'dropout_rate': 0.4753529317089179, 'learning_rate': 0.0024534975590876714, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:44:38,978] Trial 46 finished with value: 0.00033428528695367277 and parameters: {'seq_len': 12, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.24516141031421876, 'learning_rate': 0.00035142963752257396, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:45:32,535] Trial 47 finished with value: 0.00018601377087179571 and parameters: {'seq_len': 23, 'n_layers': 2, 'lstm_units': 192, 'dropout_rate': 0.2845417390160753, 'learning_rate': 0.0011181127573475066, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:45:38,206] Trial 48 finished with value: 0.0001646065356908366 and parameters: {'seq_len': 6, 'n_layers': 1, 'lstm_units': 160, 'dropout_rate': 0.31955563000613013, 'learning_rate': 0.0037310921622412748, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:45:50,557] Trial 49 finished with value: 0.0001390466932207346 and parameters: {'seq_len': 9, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.19842418350976715, 'learning_rate': 0.002008452780648297, 'batch_size': 64}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:46:04,901] Trial 50 finished with value: 0.0001275594549952075 and parameters: {'seq_len': 11, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.21862056857819917, 'learning_rate': 0.0030029227425088906, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:46:23,990] Trial 51 finished with value: 0.0001186329682241194 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.4124647426400484, 'learning_rate': 0.0036513721232355953, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:46:32,902] Trial 52 finished with value: 0.00015088565123733133 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 192, 'dropout_rate': 0.3774200180422488, 'learning_rate': 0.004720270313877295, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:46:44,829] Trial 53 finished with value: 0.00018244302191305906 and parameters: {'seq_len': 6, 'n_layers': 1, 'lstm_units': 256, 'dropout_rate': 0.4452740183906868, 'learning_rate': 0.003181652361568014, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:47:23,819] Trial 54 finished with value: 0.00011200150765944272 and parameters: {'seq_len': 10, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.4353070082237583, 'learning_rate': 0.001584617241079819, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:48:07,578] Trial 55 finished with value: 0.00014997523976489902 and parameters: {'seq_len': 13, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.3825839268161618, 'learning_rate': 0.0007308860125894497, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:48:22,705] Trial 56 finished with value: 0.00013298685371410102 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 192, 'dropout_rate': 0.23963641361914592, 'learning_rate': 0.002255680483573604, 'batch_size': 64}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:48:44,014] Trial 57 finished with value: 0.00012175307347206399 and parameters: {'seq_len': 21, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.18211986566435873, 'learning_rate': 0.008169372430258625, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:49:04,929] Trial 58 finished with value: 0.00016051209240686148 and parameters: {'seq_len': 5, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.11541594227967131, 'learning_rate': 0.0001354298414434713, 'batch_size': 32}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:49:35,898] Trial 59 finished with value: 0.00014534738147631288 and parameters: {'seq_len': 14, 'n_layers': 2, 'lstm_units': 64, 'dropout_rate': 0.364624931861925, 'learning_rate': 0.005091228875541762, 'batch_size': 16}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:49:39,570] Trial 60 finished with value: 0.00019257354142609984 and parameters: {'seq_len': 9, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.27289703030898776, 'learning_rate': 0.0038239620449159943, 'batch_size': 32}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:49:51,747] Trial 61 finished with value: 0.00012987798254471272 and parameters: {'seq_len': 15, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.393288030056229, 'learning_rate': 0.006395840966050053, 'batch_size': 32}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:49:58,026] Trial 62 finished with value: 0.00014191993977874517 and parameters: {'seq_len': 17, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.16325872060582952, 'learning_rate': 0.005585546248286982, 'batch_size': 32}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:50:18,291] Trial 63 finished with value: 0.00011192535021109506 and parameters: {'seq_len': 19, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.13773549431366283, 'learning_rate': 0.0027195198696671305, 'batch_size': 32}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:50:26,549] Trial 64 finished with value: 0.00017381021461915225 and parameters: {'seq_len': 15, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.10190708237311172, 'learning_rate': 0.007798181072801889, 'batch_size': 32}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:50:33,670] Trial 65 finished with value: 0.00014783203369006515 and parameters: {'seq_len': 12, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.18807750774571033, 'learning_rate': 0.0019002164336958001, 'batch_size': 32}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:50:37,782] Trial 66 finished with value: 0.0001707382471067831 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.2504976765133374, 'learning_rate': 0.0034625520933216766, 'batch_size': 64}. Best is trial 37 with value: 0.00011003133840858936.
# [I 2025-09-10 11:50:46,280] Trial 67 finished with value: 0.00010748428030638024 and parameters: {'seq_len': 6, 'n_layers': 1, 'lstm_units': 96, 'dropout_rate': 0.16103971350555243, 'learning_rate': 0.005889363347033941, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:50:56,699] Trial 68 finished with value: 0.0001137572035077028 and parameters: {'seq_len': 6, 'n_layers': 1, 'lstm_units': 96, 'dropout_rate': 0.33111986525725584, 'learning_rate': 0.0047629303313251525, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:51:23,541] Trial 69 finished with value: 0.00012375038932077587 and parameters: {'seq_len': 7, 'n_layers': 3, 'lstm_units': 128, 'dropout_rate': 0.12441750367301269, 'learning_rate': 0.0026356308453884783, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:51:32,843] Trial 70 finished with value: 0.0001217551834997721 and parameters: {'seq_len': 10, 'n_layers': 1, 'lstm_units': 96, 'dropout_rate': 0.2245053156441295, 'learning_rate': 0.004026781158892863, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:51:37,182] Trial 71 finished with value: 0.00015264720423147082 and parameters: {'seq_len': 5, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.1598235454069154, 'learning_rate': 0.0030627239496085904, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:51:56,792] Trial 72 finished with value: 0.00011376809561625123 and parameters: {'seq_len': 25, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.15162145746016908, 'learning_rate': 0.0057360346411775105, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:52:16,697] Trial 73 finished with value: 0.00011828487185994163 and parameters: {'seq_len': 16, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.17790184386542968, 'learning_rate': 0.00680337738879607, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:52:34,080] Trial 74 finished with value: 0.00011842705134768039 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.19942995751624373, 'learning_rate': 0.004573457827815106, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:52:57,524] Trial 75 finished with value: 0.00011642887693597004 and parameters: {'seq_len': 17, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.1405736744509224, 'learning_rate': 0.005867022322255328, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:55:38,554] Trial 76 finished with value: 0.00011491850455058739 and parameters: {'seq_len': 18, 'n_layers': 1, 'lstm_units': 256, 'dropout_rate': 0.11824087495550664, 'learning_rate': 0.009513056378100813, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:56:05,900] Trial 77 finished with value: 0.00013797843712382019 and parameters: {'seq_len': 6, 'n_layers': 2, 'lstm_units': 96, 'dropout_rate': 0.30597781623161135, 'learning_rate': 0.0014447695960068143, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:56:20,635] Trial 78 finished with value: 0.000252162863034755 and parameters: {'seq_len': 9, 'n_layers': 3, 'lstm_units': 32, 'dropout_rate': 0.17126329194315815, 'learning_rate': 0.002230937298011337, 'batch_size': 64}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:56:28,549] Trial 79 finished with value: 0.00020065810531377792 and parameters: {'seq_len': 19, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.49398777438032043, 'learning_rate': 0.0033480006172150853, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:56:59,724] Trial 80 finished with value: 0.0001165877329185605 and parameters: {'seq_len': 12, 'n_layers': 1, 'lstm_units': 224, 'dropout_rate': 0.23060844934701705, 'learning_rate': 0.007292455528521735, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:57:21,370] Trial 81 finished with value: 0.00011226770584471524 and parameters: {'seq_len': 19, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.13784391697332846, 'learning_rate': 0.0026148034217575297, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:57:35,148] Trial 82 finished with value: 0.00011655858543235809 and parameters: {'seq_len': 20, 'n_layers': 1, 'lstm_units': 96, 'dropout_rate': 0.15323451662020737, 'learning_rate': 0.003888639061428039, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:57:49,716] Trial 83 finished with value: 0.00011524155706865713 and parameters: {'seq_len': 16, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.1311379391477165, 'learning_rate': 0.0027685928901151667, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:58:00,711] Trial 84 finished with value: 0.00011234445264562964 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.11119161989356244, 'learning_rate': 0.0020803075251473783, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:58:27,188] Trial 85 finished with value: 0.00011499470565468073 and parameters: {'seq_len': 22, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.2071984817235223, 'learning_rate': 0.0017948883289815177, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:58:55,390] Trial 86 finished with value: 0.000159416813403368 and parameters: {'seq_len': 20, 'n_layers': 2, 'lstm_units': 160, 'dropout_rate': 0.16854005792102253, 'learning_rate': 0.0031231804004159753, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:59:06,138] Trial 87 finished with value: 0.00011512133642099798 and parameters: {'seq_len': 17, 'n_layers': 1, 'lstm_units': 32, 'dropout_rate': 0.13040873678459758, 'learning_rate': 0.0052367304167025884, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:59:19,005] Trial 88 finished with value: 0.00011437809007475153 and parameters: {'seq_len': 14, 'n_layers': 1, 'lstm_units': 64, 'dropout_rate': 0.14593136575920154, 'learning_rate': 0.004452611408272586, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 11:59:44,384] Trial 89 finished with value: 0.00011191295925527811 and parameters: {'seq_len': 18, 'n_layers': 1, 'lstm_units': 96, 'dropout_rate': 0.19126836249711637, 'learning_rate': 0.002473639502722423, 'batch_size': 32}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:00:03,212] Trial 90 finished with value: 0.00010891730926232412 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.18637790973582719, 'learning_rate': 0.0023603012655527833, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:00:19,644] Trial 91 finished with value: 0.00011137926048832014 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.18333442384629495, 'learning_rate': 0.0035462828629970393, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:00:29,895] Trial 92 finished with value: 0.00011858269135700539 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.1809053237916536, 'learning_rate': 0.004018050819540182, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:00:36,547] Trial 93 finished with value: 0.00013416695583146065 and parameters: {'seq_len': 6, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.15923263463258133, 'learning_rate': 0.0034785313153804067, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:01:09,547] Trial 94 finished with value: 0.00011082251876359805 and parameters: {'seq_len': 9, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.2167784400376266, 'learning_rate': 0.004905546109333339, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:01:38,759] Trial 95 finished with value: 0.00011866736895171925 and parameters: {'seq_len': 10, 'n_layers': 1, 'lstm_units': 160, 'dropout_rate': 0.21643530366155433, 'learning_rate': 0.002911658583585031, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:01:52,542] Trial 96 finished with value: 0.00012141191837145016 and parameters: {'seq_len': 7, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.20542819399338275, 'learning_rate': 0.005151481532276431, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:02:03,942] Trial 97 finished with value: 0.000156963084009476 and parameters: {'seq_len': 9, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.22516087425080414, 'learning_rate': 0.003648366845061331, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:02:16,202] Trial 98 finished with value: 0.00012100718595320359 and parameters: {'seq_len': 5, 'n_layers': 1, 'lstm_units': 160, 'dropout_rate': 0.23882629495218016, 'learning_rate': 0.0023607830298683265, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.
# [I 2025-09-10 12:02:37,780] Trial 99 finished with value: 0.00011825643014162779 and parameters: {'seq_len': 8, 'n_layers': 1, 'lstm_units': 128, 'dropout_rate': 0.19478837044679917, 'learning_rate': 0.001249791849636209, 'batch_size': 16}. Best is trial 67 with value: 0.00010748428030638024.

# %%
# ==============================================================================
# 최적화 결과 확인
# ==============================================================================
print("\n" + "="*50)
print("하이퍼파라미터 튜닝 결과")
print("="*50)
print(f"총 Trial 횟수: {len(study.trials)}")
print(f"최적의 Trial: ")
best_trial = study.best_trial
print(f"  - 값 (Validation Loss): {best_trial.value:.6f}")
print(f"  - 최적 파라미터:")
for key, value in best_trial.params.items():
    print(f"    - {key}: {value}")
# Out:
# ==================================================
# 하이퍼파라미터 튜닝 결과
# ==================================================
# 총 Trial 횟수: 100
# 최적의 Trial:
#   - 값 (Validation Loss): 0.000107
#   - 최적 파라미터:
#     - seq_len: 6
#     - n_layers: 1
#     - lstm_units: 96
#     - dropout_rate: 0.16103971350555243
#     - learning_rate: 0.005889363347033941
#     - batch_size: 32
